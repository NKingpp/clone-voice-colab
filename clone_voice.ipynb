# %% [markdown]
# <a href="https://colab.research.google.com/github/NKingpp/clone-voice-colab/blob/main/clone_voice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
from google.colab import drive
drive.mount('/content/drive')

# %env PYTHONDONTWRITEBYTECODE=1
# %cd /content/drive/MyDrive/clone-voice
# Out:
# /content
# Mounted at /content/drive
# env: PYTHONDONTWRITEBYTECODE=1
# /content/drive/MyDrive/clone-voice

# %%
# !git clone https://github.com/jianchang512/clone-voice.git
# Out:
# Cloning into 'clone-voice'...
# remote: Enumerating objects: 875, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 875 (delta 36), reused 59 (delta 29), pack-reused 767
# Receiving objects: 100% (875/875), 92.43 MiB | 15.12 MiB/s, done.
# Resolving deltas: 100% (276/276), done.
# Updating files: 100% (52/52), done.

# %%
# %cd /content/drive/MyDrive/clone-voice/clone-voice
# Out:
# /content/drive/MyDrive/clone-voice/clone-voice

# %%
# !apt install python3.10-venv -y
# !pip install virtualenv
# !virtualenv -p python3 venv1
# !. venv1/bin/activate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 23.0 MB/s eta 0:00:00
# ...
# created virtual environment CPython3.10.12.final.0-64 in 14761ms
#   creator CPython3Posix(dest=/content/drive/MyDrive/clone-voice/clone-voice/venv1, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==23.3.1, setuptools==69.0.2, wheel==0.42.0
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !pip install torch==2.1.2
# !pip install torchaudio==2.1.2
# !pip install -r requirements.txt
# !pip install python-dotenv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 997.6 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 22.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 19.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 21.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 5.6 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall numpy
# !pip install numpy
# Out:
# Found existing installation: numpy 1.22.0
# Uninstalling numpy-1.22.0:
#   Would remove:
#     /usr/local/bin/f2py
#     /usr/local/bin/f2py3
#     /usr/local/bin/f2py3.10
#     /usr/local/lib/python3.10/dist-packages/numpy-1.22.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/numpy.libs/libgfortran-040039e1.so.5.0.0
#     /usr/local/lib/python3.10/dist-packages/numpy.libs/libopenblas64_p-r0-2f7c42d4.3.18.so
#     /usr/local/lib/python3.10/dist-packages/numpy.libs/libquadmath-96973f99.so.0.0.0
#     /usr/local/lib/python3.10/dist-packages/numpy/*
# Proceed (Y/n)? y
#   Successfully uninstalled numpy-1.22.0
# ...
#   Using cached numpy-1.26.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# ...

# %%
# !wget https://johnvansickle.com/ffmpeg/releases/ffmpeg-release-amd64-static.tar.xz
# Out:
# --2024-01-04 02:29:32--  https://johnvansickle.com/ffmpeg/releases/ffmpeg-release-amd64-static.tar.xz
# Resolving johnvansickle.com (johnvansickle.com)... 107.180.57.212
# Connecting to johnvansickle.com (johnvansickle.com)|107.180.57.212|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41361568 (39M) [application/x-xz]
# Saving to: ‘ffmpeg-release-amd64-static.tar.xz’
#
# ffmpeg-release-amd6 100%[===================>]  39.45M  11.8MB/s    in 3.3s
#
# 2024-01-04 02:29:35 (11.8 MB/s) - ‘ffmpeg-release-amd64-static.tar.xz’ saved [41361568/41361568]

# %%
# prompt: 解压.xz

# !tar xvf ffmpeg-release-amd64-static.tar.xz
# !cp ffmpeg-6.1-amd64-static/ffmpeg ./
# Out:
# ffmpeg-6.1-amd64-static/
# ffmpeg-6.1-amd64-static/GPLv3.txt
# ffmpeg-6.1-amd64-static/manpages/
# ffmpeg-6.1-amd64-static/manpages/ffmpeg-all.txt
# ffmpeg-6.1-amd64-static/manpages/ffmpeg-scaler.txt
# ffmpeg-6.1-amd64-static/manpages/ffmpeg-resampler.txt
# ffmpeg-6.1-amd64-static/manpages/ffmpeg-filters.txt
# ffmpeg-6.1-amd64-static/manpages/ffprobe.txt
# ffmpeg-6.1-amd64-static/manpages/ffmpeg-devices.txt
# ffmpeg-6.1-amd64-static/manpages/ffmpeg-utils.txt
# ffmpeg-6.1-amd64-static/manpages/ffmpeg-protocols.txt
# ffmpeg-6.1-amd64-static/manpages/ffmpeg-codecs.txt
# ffmpeg-6.1-amd64-static/manpages/ffmpeg-bitstream-filters.txt
# ffmpeg-6.1-amd64-static/manpages/ffmpeg.txt
# ffmpeg-6.1-amd64-static/manpages/ffmpeg-formats.txt
# ffmpeg-6.1-amd64-static/ffprobe
# ffmpeg-6.1-amd64-static/qt-faststart
# ffmpeg-6.1-amd64-static/model/
# ffmpeg-6.1-amd64-static/model/vmaf_4k_v0.6.1.json
# ffmpeg-6.1-amd64-static/model/vmaf_rb_v0.6.3/
# ...

# %%
# !python  code_dev.py
# Out:
# 源码部署需要先运行该文件，以便同意coqou-ai协议，当弹出协议时，请输入 y
# 同时需要连接墙外下载或更新模型，请配置全局代理
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
# 2024-01-04 03:18:46.431110: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-04 03:18:46.431169: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-04 03:18:46.432168: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-04 03:18:47.662579: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#  > Using model: xtts
# ...

# %%
# !ssh-keygen -q -t rsa -N '' -f ~/.ssh/id_rsa <<<y
# !ssh-keyscan -t rsa remote.moe >> ~/.ssh/known_hosts
# !python app.py & ssh -R 80:localhost:9988 remote.moe
# Out:
# /root/.ssh/id_rsa already exists.
# Overwrite (y/n)? # remote.moe:22 SSH-2.0-Go
# http (80)
# http://pdwetxya2lvhay2waib6ficlihwegs4zch5alxpx6sm3wfdm5zjq.remote.moe/
#
# $
#
# DIR: /content/drive/MyDrive/clone-voice/clone-voice
#
# =====Source Code Deployment Notes======
# If you are deploying from source code, you need to execute the python code_dev.py file first to agree to the coqou-ai license agreement (display agreement and enter y), and then download or update the model. You need to configure the global VPN in advance
# =====
#
# Preparing to start the [Text -> Speech] thread
# Preparing to start the [Speech -> Speech] thread
# It may take a few minutes to load the model after starting, please be patient and wait for the browser to open automatically
#  > voice_conversion_models/multilingual/vctk/freevc24 is already downloaded.
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
#  > Using model: freevc
# res.status_code=200
# ...
